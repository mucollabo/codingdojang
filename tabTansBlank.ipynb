# %%
from google.colab import drive
drive.mount('./mount')
# Out:
# Mounted at ./mount

# %%
import os
import re

# %%
filename = input("Enter your file name : ")
filepath = '/content/mount/MyDrive/ColabNotebooks/codingDojang/' + filename
tempfile = open(filepath)
tempfile = tempfile.read()
temp_str = tempfile.replace("\t", "    ")
tempfile = open(filename, 'w')
tempfile.write(temp_str)
tempfile.close()
# Out:
# Enter your file name : testTab.ipynb

# %%
print(filepath)
# Out:
# /content/mount/MyDrive/ColabNotebooks/codingDojang/testTab.ipynb

# %%
print(tempfile)
# Out:
# <_io.TextIOWrapper name='testTab.ipynb' mode='w' encoding='UTF-8'>
